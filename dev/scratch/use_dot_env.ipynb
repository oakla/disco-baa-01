# %%
import dotenv
from dotenv import find_dotenv
# Reload .env with override to ensure latest values are used
dotenv.load_dotenv(find_dotenv(), override=True)
import os
os.getenv("PROJECT_ROOT")

from pathlib import Path
PROJECT_ROOT = Path(os.getenv("PROJECT_ROOT"))

import pandas as pd
RAW_DATA_DIR = Path(os.getenv("RAW_DATA_DIR"))

# %%
PROJECT_ROOT

input_file = Path(RAW_DATA_DIR, "Heat Stress Masterfile May 2024.xlsx")

# %%
pd.read_excel(input_file, sheet_name=None)
# Out:
# {'Sites':       Year State Site leader  Site            Farm  \
#  0   2022.0    WA          SH   1.0       Cuttening
#  1   2023.0    WA          SH   1.0       Cuttening
#  2   2024.0    WA          SH   1.0       Cuttening
#  3   2022.0    WA          SH   3.0          Pankee
#  4   2023.0    WA          SH   3.0          Pankee
#  5   2024.0    WA          SH   3.0          Pankee
#  6   2023.0    WA          SH   4.0      Strathmore
#  7   2024.0    WA          SH   4.0      Strathmore
#  8   2022.0    WA          DB   2.0  UWA Ridgefield
#  9   2023.0    WA          DB   2.0  UWA Ridgefield
#  10  2024.0    WA          DB   2.0  UWA Ridgefield
#  11  2023.0    WA          SH   5.0    Yuin Station
#  12  2024.0    WA          SH   5.0    Yuin Station
#  13     NaN   NaN         NaN   NaN             NaN
#  14     NaN   NaN         NaN   NaN             NaN
#  15     NaN   NaN         NaN   NaN             NaN
#  16     NaN   NaN         NaN   NaN             NaN
# ...

# %%
from dotenv import dotenv_values
config = dotenv_values(r"..\.env")
config["PROJECT_ROOT"]
# Out:
# 'E:\\\\alexa\\\\No-OneDrive\\\\Code\\\\proj\\\\disco-baa-01'

# %%
# Verify DATA_DIR from .env and resolved path
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
import os
from pathlib import Path
print("DATA_DIR env:", os.environ.get("DATA_DIR"))
print("Resolved Path:", Path(os.environ["DATA_DIR"]).resolve())
# Out:
# DATA_DIR env: E:\\alexa\\No-OneDrive\\Code\\proj\\disco-baa-01\\data
# Resolved Path: E:\alexa\No-OneDrive\Code\proj\disco-baa-01\data
