# %% [markdown]
# **What to do**
# Explore the cosinor analysis we've got already
# - graph sections of various lengths for a handful of animals
# - how do the parameters change with section length?
# - how stable are the parameters across sections?
# -   graph parameters vs section (is there a spike in mesor for one section)
