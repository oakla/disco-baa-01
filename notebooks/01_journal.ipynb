# %% [markdown]
# ### Data Ingestion
#
# **Ingest Heat Stress Masterfile.xlsx**: Convert `xlsx` with multiple sheets, a simpler format (CSV and/or Parquet) using just the sheet we are interested in (*"RF Ewe.ram data" sheet*) for clarity...
#
# run
# ```
# scripts/ingest_masterfile.py
# ```
#
# **Create Table of Temperature Logger IDs that have cosinor analysis data**:
#
# run
# ```
# scripts\ingest\scrape_cosinor_ids.py
# ```

# %% [markdown]
# ### Step 2
# Filter the masterfile for rows that match the cosinor IDs.

# %% [markdown]
# we can see that there are columns and rows that we can safely exclude from our analysis.
#
# We can also identify columns that we do need
